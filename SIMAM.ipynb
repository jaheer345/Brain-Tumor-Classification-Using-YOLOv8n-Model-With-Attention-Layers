# %%
# Install Kaggle API
# !pip install kaggle

# Create directory
# !mkdir -p ~/.kaggle

# Copy kaggle.json (must be uploaded first)
# !cp /content/kaggle.json ~/.kaggle/

# Change permissions
# !chmod 600 ~/.kaggle/kaggle.json

print("Kaggle API Successfully Configured!")
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2025.11.12)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.4.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.5.1)
# Kaggle API Successfully Configured!

# %%
# !git clone https://github.com/ultralytics/ultralytics
# %cd ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 76162, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 76162 (delta 73), reused 87 (delta 47), pack-reused 76002 (from 2)
# Receiving objects: 100% (76162/76162), 40.50 MiB | 14.17 MiB/s, done.
# Resolving deltas: 100% (57255/57255), done.
# /content/ultralytics

# %%
# !pip install -e .
import torch
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Obtaining file:///content/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.233) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.233) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.233) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.233) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.233) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.233) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.233) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.233) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.233) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.233) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.233) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics==8.3.233)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.233) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.233) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.233) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.233) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.233) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.233) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.233) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.3.233) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.3.233) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.3.233) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.3.233) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.233) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.3.233) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics==8.3.233) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics==8.3.233) (3.0.3)
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Building wheels for collected packages: ultralytics
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.3.233-0.editable-py3-none-any.whl size=23167 sha256=07c6f44550a02713ca08b9c450dc7180304f81e2e30d9e085b7bb7c091028f56
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u6cxjea9/wheels/60/e0/59/e2f034f296abbdca5c21e3f5be76b9ca685f13c7bd17f8b58c
# Successfully built ultralytics
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.233 ultralytics-thop-2.0.18
# GPU: Tesla T4

# %%
import os, shutil

print("🧹 Cleaning datasets directory...")
if os.path.exists('/content/datasets'):
    shutil.rmtree('/content/datasets')

os.makedirs('/content/datasets')

# %cd /content/datasets
# Out:
# 🧹 Cleaning datasets directory...
# /content/datasets

# %%
print("⬇️ Downloading Brain Tumor Dataset...")
# !kaggle datasets download -d pkdarabi/medical-image-dataset-brain-tumor-detection
# Out:
# ⬇️ Downloading Brain Tumor Dataset...
# Dataset URL: https://www.kaggle.com/datasets/pkdarabi/medical-image-dataset-brain-tumor-detection
# License(s): Attribution 4.0 International (CC BY 4.0)
# Downloading medical-image-dataset-brain-tumor-detection.zip to /content/datasets
#  52% 153M/297M [00:00<00:00, 1.59GB/s]
# 100% 297M/297M [00:00<00:00, 963MB/s]

# %%
print("📦 Unzipping...")
# !unzip -q medical-image-dataset-brain-tumor-detection.zip
# !rm medical-image-dataset-brain-tumor-detection.zip
# Out:
# 📦 Unzipping...

# %%
import os

print("🔍 Locating data.yaml...")

yaml_path = None

for root, dirs, files in os.walk('/content/datasets'):
    if 'data.yaml' in files:
        yaml_path = os.path.join(root, 'data.yaml')
        break

if yaml_path is None:
    raise FileNotFoundError("❌ data.yaml not found!")

dataset_root = os.path.abspath(os.path.dirname(yaml_path))

yaml_content = f"""
path: {dataset_root}
train: train/images
val: valid/images
test: test/images

nc: 3
names: ['glioma', 'meningioma', 'pituitary']
"""

with open(yaml_path, 'w') as f:
    f.write(yaml_content)

print("✅ FIXED data.yaml at:", yaml_path)
print("📍 Dataset root:", dataset_root)
# Out:
# 🔍 Locating data.yaml...
# ✅ FIXED data.yaml at: /content/datasets/BrainTumor/BrainTumorYolov11/data.yaml
# 📍 Dataset root: /content/datasets/BrainTumor/BrainTumorYolov11

# %%
import re

tasks_path = "/content/ultralytics/ultralytics/nn/tasks.py"

simam_code = """
# --- SimAM Attention START ---
# SimAM: A Simple, Parameter-Free Attention Module for CNNs
# Paper: "SimAM: A Simple, Parameter-Free Attention Module for Convolutional Neural Networks"
# This version is parameter-free, uses an energy function per neuron.

class SimAM(nn.Module):
    def __init__(self, c1=None, c2=None, e_lambda=1e-4):
        super().__init__()
        # c1, c2 kept just for YOLO parser compatibility, not used.
        self.e_lambda = e_lambda

    def forward(self, x):
        # x: (B, C, H, W)
        b, c, h, w = x.size()
        n = h * w - 1

        # deviation from mean
        x_minus_mu2 = (x - x.mean(dim=[2, 3], keepdim=True)).pow(2)

        # denominator term: 4 * (var + e_lambda)
        denom = 4 * (x_minus_mu2.sum(dim=[2, 3], keepdim=True) / n + self.e_lambda)

        # energy-based score
        y = x_minus_mu2 / denom + 0.5

        # attention weights (no parameters)
        attn = torch.sigmoid(y)

        return x * attn
# --- SimAM Attention END ---
"""

print("🔧 Injecting SimAM into tasks.py...")

# Read file
with open(tasks_path, "r") as f:
    lines = f.readlines()

# If already present, skip
if any("class SimAM" in line for line in lines):
    print("ℹ️ SimAM already exists in tasks.py, skipping insertion.")
else:
    # Find BaseModel start line
    insert_index = None
    for i, line in enumerate(lines):
        if line.strip().startswith("class BaseModel"):
            insert_index = i
            break

    if insert_index is None:
        print("❌ ERROR: Could not find class BaseModel.")
    else:
        # Insert SimAM block above BaseModel
        new_lines = lines[:insert_index] + [simam_code + "\n"] + lines[insert_index:]
        with open(tasks_path, "w") as f:
            f.writelines(new_lines)
        print("✅ SimAM class inserted above BaseModel.")

        # Register SimAM in YOLO's allowed module list (if not already)
        with open(tasks_path, "r") as f:
            content = f.read()

        if "SimAM," not in content:
            content = content.replace("if m in (", "if m in (SimAM, ", 1)
            with open(tasks_path, "w") as f:
                f.write(content)
            print("✅ SimAM registered in module list.")
        else:
            print("ℹ️ SimAM already registered in module list.")
# Out:
# 🔧 Injecting SimAM into tasks.py...
# ✅ SimAM class inserted above BaseModel.
# ✅ SimAM registered in module list.

# %%
import re

tasks_path = "/content/ultralytics/ultralytics/nn/tasks.py"

simam_code = """
# --- SimAM Attention START ---
# SimAM: A Simple, Parameter-Free Attention Module for CNNs
# Paper: "SimAM: A Simple, Parameter-Free Attention Module for Convolutional Neural Networks"
# This version is parameter-free, uses an energy function per neuron.

class SimAM(nn.Module):
    def __init__(self, c1=None, c2=None, e_lambda=1e-4):
        super().__init__()
        # c1, c2 kept just for YOLO parser compatibility, not used.
        self.e_lambda = e_lambda

    def forward(self, x):
        # x: (B, C, H, W)
        b, c, h, w = x.size()
        n = h * w - 1

        # deviation from mean
        x_minus_mu2 = (x - x.mean(dim=[2, 3], keepdim=True)).pow(2)

        # denominator term: 4 * (var + e_lambda)
        denom = 4 * (x_minus_mu2.sum(dim=[2, 3], keepdim=True) / n + self.e_lambda)

        # energy-based score
        y = x_minus_mu2 / denom + 0.5

        # attention weights (no parameters)
        attn = torch.sigmoid(y)

        return x * attn
# --- SimAM Attention END ---
"""

print("🔧 Injecting SimAM into tasks.py...")

# Read file
with open(tasks_path, "r") as f:
    lines = f.readlines()

# If already present, skip
if any("class SimAM" in line for line in lines):
    print("ℹ️ SimAM already exists in tasks.py, skipping insertion.")
else:
    # Find BaseModel start line
    insert_index = None
    for i, line in enumerate(lines):
        if line.strip().startswith("class BaseModel"):
            insert_index = i
            break

    if insert_index is None:
        print("❌ ERROR: Could not find class BaseModel.")
    else:
        # Insert SimAM block above BaseModel
        new_lines = lines[:insert_index] + [simam_code + "\n"] + lines[insert_index:]
        with open(tasks_path, "w") as f:
            f.writelines(new_lines)
        print("✅ SimAM class inserted above BaseModel.")

        # Register SimAM in YOLO's allowed module list (if not already)
        with open(tasks_path, "r") as f:
            content = f.read()

        if "SimAM," not in content:
            content = content.replace("if m in (", "if m in (SimAM, ", 1)
            with open(tasks_path, "w") as f:
                f.write(content)
            print("✅ SimAM registered in module list.")
        else:
            print("ℹ️ SimAM already registered in module list.")
# Out:
# 🔧 Injecting SimAM into tasks.py...
# ℹ️ SimAM already exists in tasks.py, skipping insertion.

# %%
simam_yaml = """
# YOLOv8n + SimAM (parameter-free attention)

nc: 3  # adjust if friend has different number of classes

backbone:
  - [-1, 1, Conv, [64, 3, 2]]
  - [-1, 1, Conv, [128, 3, 2]]
  - [-1, 3, C2f, [128, True]]
  - [-1, 1, Conv, [256, 3, 2]]
  - [-1, 6, C2f, [256, True]]
  - [-1, 1, Conv, [512, 3, 2]]
  - [-1, 6, C2f, [512, True]]
  - [-1, 1, Conv, [1024, 3, 2]]
  - [-1, 3, C2f, [1024, True]]
  - [-1, 1, SPPF, [1024, 5]]

  # SimAM at deepest feature map (no learnable params, c1 not really used)
  - [-1, 1, SimAM, [1024]]

head:
  - [-1, 1, nn.Upsample, [None, 2, 'nearest']]
  - [[-1, 6], 1, Concat, [1]]
  - [-1, 3, C2f, [512]]

  - [-1, 1, nn.Upsample, [None, 2, 'nearest']]
  - [[-1, 4], 1, Concat, [1]]
  - [-1, 3, C2f, [256]]

  - [-1, 1, Conv, [256, 3, 2]]
  - [[-1, 13], 1, Concat, [1]]
  - [-1, 3, C2f, [512]]

  - [-1, 1, Conv, [512, 3, 2]]
  - [[-1, 10], 1, Concat, [1]]
  - [-1, 3, C2f, [1024]]

  - [[16, 19, 22], 1, Detect, [nc]]
"""

with open("/content/ultralytics/yolov8n-simam.yaml", "w") as f:
    f.write(simam_yaml)

print("✅ Created yolov8n-simam.yaml")
# Out:
# ✅ Created yolov8n-simam.yaml

# %%
# %cd /content/ultralytics
import os
os.environ["WANDB_DISABLED"] = "true"

# !yolo detect train \
  data=/content/datasets/BrainTumor/BrainTumorYolov11/data.yaml \
  model=/content/ultralytics/yolov8n-simam.yaml \
  epochs=50 \
  imgsz=640 \
  batch=16 \
  name=YOLOv8_SimAM
# Out:
# /content/ultralytics
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/datasets/BrainTumor/BrainTumorYolov11/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/ultralytics/yolov8n-simam.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=YOLOv8_SimAM, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/ultralytics/runs/detect/YOLOv8_SimAM, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 130.9MB/s 0.0s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   4720640  ultralytics.nn.modules.conv.Conv             [512, 1024, 3, 2]
#   8                  -1  3  17836032  ultralytics.nn.modules.block.C2f             [1024, 1024, 3, True]
#   9                  -1  1   2624512  ultralytics.nn.modules.block.SPPF            [1024, 1024, 5]
#  10                  -1  1         0  ultralytics.nn.tasks.SimAM                   [1024]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  3   4985856  ultralytics.nn.modules.block.C2f             [1536, 512, 3]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   4592640  ultralytics.nn.modules.block.C2f             [768, 512, 3]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  3  18360320  ultralytics.nn.modules.block.C2f             [1536, 1024, 3]
#  23        [16, 19, 22]  1   7059673  ultralytics.nn.modules.head.Detect           [3, [256, 512, 1024]]
# YOLOv8n-simam summary: 210 layers, 76,707,865 parameters, 76,707,849 gradients, 192.5 GFLOPs
#
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 205.0MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1201.2±414.8 MB/s, size: 32.5 KB)
# train: Scanning /content/datasets/BrainTumor/BrainTumorYolov11/train/labels... 2144 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2144/2144 2.2Kit/s 1.0s
# train: New cache created: /content/datasets/BrainTumor/BrainTumorYolov11/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2143, len(boxes) = 2144. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 595.8±302.0 MB/s, size: 31.8 KB)
# val: Scanning /content/datasets/BrainTumor/BrainTumorYolov11/valid/labels... 612 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 612/612 1.5Kit/s 0.4s
# val: New cache created: /content/datasets/BrainTumor/BrainTumorYolov11/valid/labels.cache
# Plotting labels to /content/ultralytics/runs/detect/YOLOv8_SimAM/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/ultralytics/runs/detect/YOLOv8_SimAM
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50        10G       3.12      4.695       3.82         31        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.4it/s 13.9s
#                    all        612        612      0.356     0.0258     0.0101    0.00236
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      10.9G       2.45      3.604       2.98         24        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.5it/s 13.0s
#                    all        612        612      0.175      0.335      0.154     0.0743
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      10.5G      2.053      2.818      2.571         20        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.6s
#                    all        612        612      0.133      0.144     0.0584     0.0296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      10.5G      1.841      2.499      2.332         30        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.6s
#                    all        612        612      0.364      0.364      0.303       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      10.9G      1.697      2.302       2.21         25        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.6s
#                    all        612        612      0.364      0.271      0.237      0.123
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      10.6G      1.662      2.183       2.16         20        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.534      0.387      0.401      0.242
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      10.5G      1.623      2.112      2.106         35        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.5s
#                    all        612        612      0.503      0.387      0.419      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      10.9G       1.55      1.993      2.041         29        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.554      0.501      0.528      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      10.5G      1.494      1.885      1.996         23        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.605      0.557      0.599      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      10.5G      1.453      1.817       1.94         17        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.5s
#                    all        612        612      0.745      0.508        0.6       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      10.9G      1.455      1.771      1.948         30        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.687      0.538      0.624      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      10.9G      1.437      1.748      1.917         28        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.654      0.545      0.599      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      10.9G      1.377      1.731       1.86         28        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.5s
#                    all        612        612      0.625      0.453      0.503      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      10.9G      1.389       1.67      1.872         19        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612        0.7      0.274      0.404      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      10.9G      1.361      1.613      1.865         26        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.584      0.333      0.336      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      10.8G      1.323      1.565      1.831         18        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612        0.6      0.645      0.664      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      10.9G      1.298      1.528      1.787         20        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.5s
#                    all        612        612      0.663      0.488      0.556      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      10.9G      1.307      1.504      1.786         24        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612       0.69      0.601      0.665      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      10.9G      1.281      1.437       1.76         24        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.718      0.635      0.697      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      10.9G      1.272      1.428      1.767         30        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.693      0.657      0.726        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      10.9G      1.285      1.404      1.779         28        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.685      0.631      0.704      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      10.8G      1.237      1.358      1.716         29        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.694      0.689      0.732      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      10.9G       1.23      1.345      1.708         20        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612       0.73      0.696       0.74       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      10.8G      1.219      1.277      1.699         20        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.708        0.7      0.742      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      10.9G      1.212        1.3      1.708         29        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.7it/s 12.1s
#                    all        612        612      0.783      0.689      0.765      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      10.5G      1.215      1.281      1.697         26        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.2s
#                    all        612        612      0.761      0.733      0.801      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      10.9G      1.198      1.263      1.685         15        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.722      0.726      0.777      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      10.5G       1.17      1.216      1.654         23        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.5s
#                    all        612        612      0.732      0.712      0.777      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      10.9G      1.125      1.161      1.615         21        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.747      0.744      0.788      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      10.9G      1.172      1.252      1.673         27        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.774      0.712      0.787      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      10.9G      1.152       1.19       1.63         28        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.798      0.696      0.779      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      10.9G      1.121      1.145      1.604         28        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.766      0.783      0.816      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      10.8G      1.119      1.151      1.626         21        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.796      0.735      0.803      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      10.9G      1.102      1.083      1.585         32        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.699      0.779      0.809       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      10.9G      1.085      1.051      1.569         35        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612       0.81      0.769      0.843      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      10.9G      1.081       1.05      1.582         25        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.803      0.751      0.816      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      10.5G      1.082      1.041      1.577         20        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.793      0.741      0.803      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      10.9G      1.067       1.04      1.555         31        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.756      0.629       0.73       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      10.5G      1.061      1.025      1.549         31        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.808      0.791      0.852      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      10.9G      1.019     0.9603      1.527         24        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.785       0.75      0.805      0.582
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      10.9G     0.9636     0.9365      1.567         16        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.757      0.815       0.85       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      10.8G     0.9229     0.8275      1.534         16        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.807      0.801       0.86      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      10.5G     0.9203     0.8173      1.523         16        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.821      0.813      0.869      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      10.9G     0.8872     0.7748      1.486         16        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.859      0.799      0.875      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      10.9G     0.8777     0.7736      1.477         16        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.4s
#                    all        612        612      0.839      0.815      0.872       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      10.9G     0.8702     0.7516      1.471         16        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.828      0.822      0.877      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      10.9G     0.8548     0.7134       1.45         16        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.839      0.833      0.889      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      10.9G     0.8449     0.7138      1.449         16        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612       0.86      0.826       0.89      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      10.6G     0.8256     0.6982      1.425         16        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.824      0.849      0.888       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      10.6G     0.8101     0.6773      1.409         16        640: 100% ━━━━━━━━━━━━ 134/134 1.2it/s 1:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.6it/s 12.3s
#                    all        612        612      0.858      0.823      0.889       0.66
#
# 50 epochs completed in 2.225 hours.
# Optimizer stripped from /content/ultralytics/runs/detect/YOLOv8_SimAM/weights/last.pt, 153.8MB
# Optimizer stripped from /content/ultralytics/runs/detect/YOLOv8_SimAM/weights/best.pt, 153.8MB
#
# Validating /content/ultralytics/runs/detect/YOLOv8_SimAM/weights/best.pt...
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-simam summary (fused): 113 layers, 76,678,233 parameters, 0 gradients, 191.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 1.5it/s 12.9s
#                    all        612        612      0.823       0.85      0.889      0.661
#                 glioma        285        285       0.72      0.709      0.773      0.481
#             meningioma        142        142      0.893      0.915      0.962      0.788
#              pituitary        185        185      0.855      0.924      0.934      0.714
# Speed: 0.2ms preprocess, 16.5ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /content/ultralytics/runs/detect/YOLOv8_SimAM
# 💡 Learn more at https://docs.ultralytics.com/modes/train
